# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayoub-Moutaouakil/ProjetPythonDA/blob/main/ProjetPythonDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aujourd'hui, la plupart des vols dans le monde entier sont dirigés en pilote automatique. Une machine contrôle l'avion depuis le décollage jusqu'à l'atterrisage. Cependant l'humain prend la relève de la machine dans plusieurs cas :
#
# - Perturbations météo
# - Erreur du pilote automatique
# - Probléme moteur
# - etc...
#
# Nos pilotes de ligne aujourd'hui sont formés à pouvoir réagir à tout type de situation. Malheureusement certains accidents sont toujours inévitables et provoquent des morts. On est donc ammener à se poser cette question :
#
# ### **Quels sont les facteurs qu'il faut le plus améliorer pour éviter au mieux les accidents ?**
#
# Pour cela nous allons analyser un dataset contenant des données sur les accidents aériens bréziliens, ce qui permettra de définir le probléme de construction des avions au Brézil. Nous pourrons donc aussi retranscrire ces données sur une globalité mondial.

# %% [markdown]
# ---
# Lecture des données
# ---
# ---

# %% [markdown]
# Importation et configuration des librairies

# %%
import pandas
import numpy
import seaborn
import matplotlib
import matplotlib.pyplot as plt

pandas.set_option('display.max_columns', None)

# %% [markdown]
# Lecture des données contenant les informations des avions (date de construction, type de moteur, numéro d'identification, etc...)

# %%
aircrafts = pandas.read_csv('/content/aircrafts.csv', header=0, encoding='latin-1')
aircrafts = aircrafts.replace(numpy.nan, 0)
aircrafts.head()
# Out:
#    Unnamed: 0  aircraft_id  occurrence_id registration  operator_id equipment  \
# 0           0            4          45602        PPGXE          241  AIRPLANE
# 1           1           40          53551        PPGSZ          160  AIRPLANE
# 2           2          118          43721        PTCMT         1232  AIRPLANE
# 3           3          130          35556        PTEQI         3992  AIRPLANE
# 4           4          191          32579        PPVMM         4365  AIRPLANE
#
#                   manufacturer     model engine_type  engines_amount  \
# 0  NEIVA INDUSTRIA AERONAUTICA      56-C      PISTON             1.0
# 1  NEIVA INDUSTRIA AERONAUTICA      56-C      PISTON             1.0
# 2               BEECH AIRCRAFT    95-B55      PISTON             2.0
# 3  NEIVA INDUSTRIA AERONAUTICA  EMB-721C      PISTON             1.0
# 4               BOEING COMPANY   737-241         JET             2.0
#
#    takeoff_max_weight (Lbs)  seatings_amount  year_manufacture  \
# ...

# %% [markdown]
# Lecture des données contenant les informations sur les accidents des avions bréziliens (type d'accident, endroit, mortalité, etc...)

# %%
occurrences = pandas.read_csv('/content/occurrences.csv', header=0, encoding='latin-1')
occurrences = occurrences.replace(numpy.nan, 0)
occurrences.head()
# Out:
#    Unnamed: 0  occurrence_id    classification  \
# 0           0          47965          ACCIDENT
# 1           1          50313  SERIOUS INCIDENT
# 2           2          34078          ACCIDENT
# 3           3          44988          ACCIDENT
# 4           4          38855          ACCIDENT
#
#                  type of occurrence localization  fu country aerodrome  \
# 0  ENGINE FAILURE DURING THE FLIGHT    ARIQUEMES  RO  BRAZIL      SJOG
# 1      LANDING WITHOUT LANDING GEAR       CACOAL  RO  BRAZIL      SSKW
# 2     LOSS OF CONTROL ON THE GROUND   CEREJEIRAS  RO  BRAZIL      ****
# 3                      SLOW LANDING      AMAJARI  RR  BRAZIL      ****
# 4        LOSS OF CONTROL IN THE AIR       ACEGUÁ  RS  BRAZIL      ****
#
#   occurrence_day      time under_investigation investigating_command  \
# 0     2013-05-05  11:00:00             UNKNOWN              SERIPA-7
# 1     2013-11-25  12:32:00                 YES              SERIPA-7
# ...

# %% [markdown]
# Les accidents sont représentés par deux types de catégories :

# %%
print(occurrences['classification'].unique())
# Out:
# ['ACCIDENT' 'SERIOUS INCIDENT']

# %% [markdown]
# Voyons voir le nombre d'accidents par type :

# %%
print('Total: ' + str(occurrences['classification'].count()))

print('SERIOUS INCIDENT: ' + str(occurrences['classification'][occurrences['classification'] == 'SERIOUS INCIDENT'].count()))

print('ACCIDENT: ' + str(occurrences['classification'][occurrences['classification'] == 'ACCIDENT'].count()))
# Out:
# Total: 2027
# SERIOUS INCIDENT: 552
# ACCIDENT: 1475

# %% [markdown]
# On remarque qu'il y'a plus d'accidents que d'incident sérieux

# %% [markdown]
# Fusion des deux datasets

# %%
mergetable = aircrafts.join(occurrences, lsuffix="_left", rsuffix="_right")
mergetable = mergetable.replace(numpy.nan, 0)
mergetable = mergetable[(mergetable['classification'] != 0)]
mergetable = mergetable[(mergetable['engine_type'] != 'UNKNOWN')]
mergetable = mergetable[(mergetable['type of occurrence'] != 'UNKNOWN')]
mergetable = mergetable[(mergetable['equipment'] == "AIRPLANE")]
mergetable.head()
# Out:
#    Unnamed: 0_left  aircraft_id  occurrence_id_left registration  operator_id  \
# 0                0            4               45602        PPGXE          241
# 1                1           40               53551        PPGSZ          160
# 2                2          118               43721        PTCMT         1232
# 3                3          130               35556        PTEQI         3992
# 4                4          191               32579        PPVMM         4365
#
#   equipment                 manufacturer     model engine_type  \
# 0  AIRPLANE  NEIVA INDUSTRIA AERONAUTICA      56-C      PISTON
# 1  AIRPLANE  NEIVA INDUSTRIA AERONAUTICA      56-C      PISTON
# 2  AIRPLANE               BEECH AIRCRAFT    95-B55      PISTON
# 3  AIRPLANE  NEIVA INDUSTRIA AERONAUTICA  EMB-721C      PISTON
# 4  AIRPLANE               BOEING COMPANY   737-241         JET
#
#    engines_amount  takeoff_max_weight (Lbs)  seatings_amount  \
# ...

# %% [markdown]
# ---
# Analyse des données
# ---
# ---

# %%
seaborn.barplot(data=mergetable, x='classification', y='fatalities_amount')

# %% [markdown]
# On remarque qu'il y'a plus de morts pour un accident qu'un incident sérieux. Le but serait donc en priorité de réduire au maximum le nombre d'accidents.

# %%
f, ax = plt.subplots(figsize = (20,20))
seaborn.barplot(data=mergetable, x='fatalities_amount', y='type of occurrence')
plt.xticks(rotation=90)
# Out:
# (array([0., 1., 2., 3., 4., 5., 6.]),
#  <a list of 7 Text major ticklabel objects>)

# %% [markdown]
# Cet histogramme nous indique le pourcentage de mort selon le type d'accident

# %%
pays_frequence_dic = {}

for occ in mergetable['fu'].unique(): 
    pays_frequence_dic[occ] = mergetable['fu'][mergetable['fu'] == occ].count() / mergetable['fu'].count()
    
pays_frequence = pandas.Series(pays_frequence_dic)

fig, axes = plt.subplots(figsize=(10.,6.))

pays_frequence.sort_values(ascending=False).plot(kind='bar')

axes.set_xlabel('State')
axes.set_ylabel('Flight occurrence rate')
                   
plt.show()
plt.close()

# %% [markdown]
# Voici un histogramme démontrant le taux d'accidents ou incidents sérieux (autrement dit une occurence) pour chaque destination. On remaque que le taux d'occurence est élévé pour l'Espagne. On peux alors définir un besoin d'amélioration des facteurs des avions en direction de l'Espagne.

# %%
f, ax = plt.subplots(figsize = (20,20))
seaborn.barplot(data=mergetable[mergetable['fu'] == 'SP'], x='fatalities_amount', y='type of occurrence')
plt.xticks(rotation=90)
# Out:
# (array([0., 1., 2., 3., 4., 5., 6.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
f, ax = plt.subplots(figsize = (10,10))
seaborn.barplot(data=mergetable[mergetable['type of occurrence'] == 'ENGINE FAILURE DURING THE FLIGHT'], x='engine_type', y='fatalities_amount')
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2]), <a list of 3 Text major ticklabel objects>)

# %%
f, ax = plt.subplots(figsize = (20,20))
seaborn.barplot(data=mergetable[mergetable['engine_type'] == 'JET'], x='fatalities_amount', y='model')
plt.xticks(rotation=0)
# Out:
# (array([  0.,  25.,  50.,  75., 100., 125., 150., 175., 200., 225.]),
#  <a list of 10 Text major ticklabel objects>)

# %%
mergetable.replace(
    to_replace=['UNKNOWN', 'NONE', 'LIGHT', 'SUBSTANTIAL', 'DESTROYED'],
    value=[numpy.nan, 0, 1, 2, 3],
    inplace=True
    )

label_lst = ['fatalities_amount', 
             'damage_level',
             'engines_amount',
             'seatings_amount',
             'takeoff_max_weight (Lbs)',
             'year_manufacture'
            ]

fig, axes = plt.subplots()

seaborn.heatmap(mergetable[label_lst].corr(method='pearson'), annot=True)

plt.xticks(rotation=90)
    
plt.show()
plt.close()

# %%
plt.scatter(mergetable["damage_level"], mergetable["fatalities_amount"])
plt.show()

# %% [markdown]
# ---
# Conclusion
# ---
# ---

# %%
Les principaux facteurs à améliorer afin de reduire le taux d'accidents et de serieux incidents dans le monde de l'aéronautique sont

# %%
manuf_year_freq_dict = {}

manuf_year_lst = mergetable['year_manufacture'].unique()

# Exclude 'nan' and '0'
manuf_year_lst = manuf_year_lst[~numpy.isnan(manuf_year_lst)]
manuf_year_lst[ manuf_year_lst != 0.]

for y in manuf_year_lst:
    manuf_year_freq_dict[y] = mergetable['year_manufacture'][
                                        mergetable['year_manufacture'] == y
                                        ].count()
    
manuf_year_freq = pandas.Series(manuf_year_freq_dict)
fig, axes = plt.subplots(figsize=(10.,6.))

manuf_year_freq.plot.area(alpha=0.5)

axes.set_xlabel('Year of aircraft manufacture')
axes.set_ylabel('Occurrences in 10 years')
axes.set_xlim(xmin=1936) 

plt.show()
plt.close()
